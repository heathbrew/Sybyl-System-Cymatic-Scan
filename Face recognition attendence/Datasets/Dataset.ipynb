# %%
import pandas as pd

df = pd.read_csv('cleaned_finalized.csv')

df
# Out:
#      Unnamed: 0                         Name                   Country  \
# 0             0            Carl Eugene Watts             United States
# 1             1               Philipp Tyurin              Soviet Union
# 2             2          Zdzislaw Marchwicki                    Poland
# 3             3          Monster of Florence                     Italy
# 4             4                Joachim Kroll              West Germany
# ..          ...                          ...                       ...
# 300         300         Ali Asghar Borujerdi  Ottoman Empire,Iraq,Iran
# 301         301              Vasili Komaroff              Soviet Union
# 302         302     Fernando Hernandez Leyva                    Mexico
# 303         303  Ramadan Abdel Rehim Mansour                     Egypt
# 304         304                Radik Tagirov                    Russia
#
#      Years active  Possible victims(Updated)  Proven victims(Updated)  \
# ...

# %%
df2 = pd.DataFrame(df)
df2
# Out:
#      Unnamed: 0                         Name                   Country  \
# 0             0            Carl Eugene Watts             United States
# 1             1               Philipp Tyurin              Soviet Union
# 2             2          Zdzislaw Marchwicki                    Poland
# 3             3          Monster of Florence                     Italy
# 4             4                Joachim Kroll              West Germany
# ..          ...                          ...                       ...
# 300         300         Ali Asghar Borujerdi  Ottoman Empire,Iraq,Iran
# 301         301              Vasili Komaroff              Soviet Union
# 302         302     Fernando Hernandez Leyva                    Mexico
# 303         303  Ramadan Abdel Rehim Mansour                     Egypt
# 304         304                Radik Tagirov                    Russia
#
#      Years active  Possible victims(Updated)  Proven victims(Updated)  \
# ...

# %%
df2["Poss&Prov"] = abs(df2["Possible victims(Updated)"] - df2["Proven victims(Updated)"])
df2
# Out:
#      Unnamed: 0                         Name                   Country  \
# 0             0            Carl Eugene Watts             United States
# 1             1               Philipp Tyurin              Soviet Union
# 2             2          Zdzislaw Marchwicki                    Poland
# 3             3          Monster of Florence                     Italy
# 4             4                Joachim Kroll              West Germany
# ..          ...                          ...                       ...
# 300         300         Ali Asghar Borujerdi  Ottoman Empire,Iraq,Iran
# 301         301              Vasili Komaroff              Soviet Union
# 302         302     Fernando Hernandez Leyva                    Mexico
# 303         303  Ramadan Abdel Rehim Mansour                     Egypt
# 304         304                Radik Tagirov                    Russia
#
#      Years active  Possible victims(Updated)  Proven victims(Updated)  \
# ...

# %% [markdown]
# # Remove columns as index base
#
# df2.drop(df2.columns[[8]], axis=1, inplace=True)
#
# df2

# %%
df2["CrimeCofficient"] = round((df2["Possible victims(Updated)"] / df2["Poss&Prov"]),2)
df2
# Out:
#                             Name                   Country  Years active  \
# 0              Carl Eugene Watts             United States  1974 to 1982
# 1                 Philipp Tyurin              Soviet Union  1945 to 1946
# 2            Zdzislaw Marchwicki                    Poland  1964 to 1970
# 3            Monster of Florence                     Italy  1968 to 1985
# 4                  Joachim Kroll              West Germany  1955 to 1976
# ..                           ...                       ...           ...
# 300         Ali Asghar Borujerdi  Ottoman Empire,Iraq,Iran  1907 to 1934
# 301              Vasili Komaroff              Soviet Union  1921 to 1923
# 302     Fernando Hernandez Leyva                    Mexico  1982 to 1999
# 303  Ramadan Abdel Rehim Mansour                     Egypt  1999 to 2006
# 304                Radik Tagirov                    Russia  2011 to 2012
#
#      Possible victims(Updated)  Proven victims(Updated)  \
# ...

# %%
df2["CrimeCofficient"].unique()
# Out:
# array([ 1.21,  1.93,  3.  ,  8.  ,  0.  ,  1.42,  1.48,  1.52,  2.86,
#         5.33,  7.5 ,   inf,  1.14,  2.  ,  2.2 ,  2.5 ,  3.4 ,  5.  ,
#        13.  ,  1.09,  1.38, 10.  ,  0.1 ,  3.75,  6.5 ,  1.67,  2.43,
#         3.5 ,  4.33, 11.  ,  1.12,  1.1 ,  1.13,  1.36,  1.69,  1.82,
#         2.12,  2.8 ,  5.5 ,  1.18,  1.05,  1.07,  1.57,  1.89,  2.6 ,
#         1.39,  1.17,  1.19,  1.64,  2.75,  3.33,  1.25,  1.43,  1.75,
#         1.86,  1.16,  4.  ,  1.29,  2.67,  1.83,  1.33,  1.4 ,  1.44,
#         1.5 ,  1.06,  1.11,  1.23,  1.27,  1.6 ,  2.65,  4.38,  9.  ,
#         8.33,  1.72,  1.95,  2.4 ,  5.2 ,  1.3 ,  5.75,  2.73,  2.06,
#         7.  ,  3.12,  3.83,  9.5 ,  0.07,  6.33, 17.  ,  6.  ,  0.86,
#         1.58,  3.45,  2.82, 18.67,  0.22,  0.14,  0.38,  0.2 , 10.67,
#        34.  ,  1.49])

# %%
# Remove columns as index base

df2.drop(df2.columns[[7]], axis=1, inplace=True)

df2
# Out:
#                             Name                   Country  Years active  \
# 0              Carl Eugene Watts             United States  1974 to 1982
# 1                 Philipp Tyurin              Soviet Union  1945 to 1946
# 2            Zdzislaw Marchwicki                    Poland  1964 to 1970
# 3            Monster of Florence                     Italy  1968 to 1985
# 4                  Joachim Kroll              West Germany  1955 to 1976
# ..                           ...                       ...           ...
# 300         Ali Asghar Borujerdi  Ottoman Empire,Iraq,Iran  1907 to 1934
# 301              Vasili Komaroff              Soviet Union  1921 to 1923
# 302     Fernando Hernandez Leyva                    Mexico  1982 to 1999
# 303  Ramadan Abdel Rehim Mansour                     Egypt  1999 to 2006
# 304                Radik Tagirov                    Russia  2011 to 2012
#
#      Possible victims(Updated)  Proven victims(Updated)  \
# ...

# %%
df2["CrimeCofficient"] = round((df2["Poss&Prov"] / df2["Proven victims(Updated)"]),2)
df2
# Out:
#                             Name                   Country  Years active  \
# 0              Carl Eugene Watts             United States  1974 to 1982
# 1                 Philipp Tyurin              Soviet Union  1945 to 1946
# 2            Zdzislaw Marchwicki                    Poland  1964 to 1970
# 3            Monster of Florence                     Italy  1968 to 1985
# 4                  Joachim Kroll              West Germany  1955 to 1976
# ..                           ...                       ...           ...
# 300         Ali Asghar Borujerdi  Ottoman Empire,Iraq,Iran  1907 to 1934
# 301              Vasili Komaroff              Soviet Union  1921 to 1923
# 302     Fernando Hernandez Leyva                    Mexico  1982 to 1999
# 303  Ramadan Abdel Rehim Mansour                     Egypt  1999 to 2006
# 304                Radik Tagirov                    Russia  2011 to 2012
#
#      Possible victims(Updated)  Proven victims(Updated)  \
# ...

# %%
df2["CrimeCofficient"] = df2["CrimeCofficient"].replace([0.00], 1.00)

# %%
df2
# Out:
#                             Name                   Country  Years active  \
# 0              Carl Eugene Watts             United States  1974 to 1982
# 1                 Philipp Tyurin              Soviet Union  1945 to 1946
# 2            Zdzislaw Marchwicki                    Poland  1964 to 1970
# 3            Monster of Florence                     Italy  1968 to 1985
# 4                  Joachim Kroll              West Germany  1955 to 1976
# ..                           ...                       ...           ...
# 300         Ali Asghar Borujerdi  Ottoman Empire,Iraq,Iran  1907 to 1934
# 301              Vasili Komaroff              Soviet Union  1921 to 1923
# 302     Fernando Hernandez Leyva                    Mexico  1982 to 1999
# 303  Ramadan Abdel Rehim Mansour                     Egypt  1999 to 2006
# 304                Radik Tagirov                    Russia  2011 to 2012
#
#      Possible victims(Updated)  Proven victims(Updated)  \
# ...

# %%
df2.to_csv("fetcher.csv")
