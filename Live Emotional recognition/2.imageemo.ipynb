# %%
import cv2
import face_recognition
import matplotlib.pyplot as plt

# %%
imgimported = plt.imread('happyface.jpg')
if(imgimported is not None):
    img = cv2.cvtColor(imgimported,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imgimported)

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(imgimported,cv2.COLOR_BGR2RGB)

# %%
from deepface import DeepFace

# %%
predictions = DeepFace.analyze(img)
# Out:
# ...
# Action: race: 100%|██████████████████████████████████████████████████████| 4/4 [00:00<00:00,  5.26it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 7.436314342079697e-08,
#   'disgust': 7.282695809083256e-16,
#   'fear': 3.708500173615903e-09,
#   'happy': 99.99755620956421,
#   'sad': 6.501619121551672e-10,
#   'surprise': 9.364493536168084e-06,
#   'neutral': 0.002433323606965132},
#  'dominant_emotion': 'happy',
#  'region': {'x': 361, 'y': 18, 'w': 462, 'h': 462},
#  'age': 25,
#  'gender': 'Man',
#  'race': {'asian': 1.2212179601192474,
#   'indian': 1.372089795768261,
#   'black': 0.06881298031657934,
#   'white': 48.65282475948334,
#   'middle eastern': 19.862934947013855,
#   'latino hispanic': 28.822121024131775},
#  'dominant_race': 'white'}

# %%
type(predictions)
# Out:
# dict

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %% [markdown]
# # we are trying to draw a rectangle across the face

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)

# %%
# Draw a rectangle around the faces
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
font = cv2.FONT_HERSHEY_SIMPLEX
#Use putText() method for

# %%
#inserting text on video
cv2.putText(img,predictions['dominant_emotion'],
            (55,100),
            font,3,(0,0,255),
            2,cv2.LINE_4);

# %%
plt.imshow(img)

# %%
imgimported = plt.imread('neutralface.jpg')
if(imgimported is not None):
    img = cv2.cvtColor(imgimported,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imgimported)

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(imgimported,cv2.COLOR_BGR2RGB)

# %%
predictions = DeepFace.analyze(img)
predictions
# Out:
# ...
# Action: race: 100%|██████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.32it/s]
# {'emotion': {'angry': 0.07678314577788115,
#   'disgust': 5.927218438284143e-09,
#   'fear': 1.6007041558623314,
#   'happy': 1.6192403506920527e-05,
#   'sad': 19.426925480365753,
#   'surprise': 0.20616799592971802,
#   'neutral': 78.68940234184265},
#  'dominant_emotion': 'neutral',
#  'region': {'x': 55, 'y': 3, 'w': 300, 'h': 300},
#  'age': 29,
#  'gender': 'Woman',
#  'race': {'asian': 0.08213772274215844,
#   'indian': 0.044825024565120095,
#   'black': 0.007228212646244821,
#   'white': 89.45908672105232,
#   'middle eastern': 3.658391844225902,
#   'latino hispanic': 6.748326063355677},
#  'dominant_race': 'white'}

# %%
predictions['dominant_emotion']
# Out:
# 'neutral'

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')
# Draw a rectangle around the faces
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#print(faceCascade.empty())
faces = faceCascade.detectMultiScale(gray,1.1,4)
for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
#inserting text on video
cv2.putText(img,predictions['dominant_emotion'],
            (55,100),
            font,3,(0,0,255),
            2,cv2.LINE_4);

# %%
plt.imshow(img)

# %%
predictions['gender']
# Out:
# 'Woman'

# %%
predictions['dominant_race']
# Out:
# 'white'

# %%
imgimported = plt.imread('aisha.jpg')
if(imgimported is not None):
    img = cv2.cvtColor(imgimported,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imgimported)

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(imgimported,cv2.COLOR_BGR2RGB)

# %%
predictions = DeepFace.analyze(img)
predictions
# Out:
# ...
# Action: race: 100%|██████████████████████████████████████████████████████| 4/4 [00:00<00:00,  5.79it/s]
# {'emotion': {'angry': 2.9040116553320474,
#   'disgust': 1.0498845712031384e-05,
#   'fear': 0.13768726971370215,
#   'happy': 0.2939751023694995,
#   'sad': 6.137921647777754,
#   'surprise': 0.026405064510040224,
#   'neutral': 90.49999004602313},
#  'dominant_emotion': 'neutral',
#  'region': {'x': 52, 'y': 117, 'w': 169, 'h': 169},
#  'age': 31,
#  'gender': 'Woman',
#  'race': {'asian': 2.0629068836569786,
#   'indian': 13.21006864309311,
#   'black': 1.5657218173146248,
#   'white': 7.340692728757858,
#   'middle eastern': 3.6516834050416946,
#   'latino hispanic': 72.16892838478088},
#  'dominant_race': 'latino hispanic'}

# %%
predictions['dominant_emotion']
# Out:
# 'neutral'

# %%
predictions['gender']
# Out:
# 'Woman'

# %%
predictions['dominant_race']
# Out:
# 'latino hispanic'
